# %%
import os

print('getcwd:      ', os.getcwd())

# %%
# importing pandas as pd
import pandas as pd
# Creating the dataframe 
df = pd.read_csv("SalesRecords.csv")
pd.set_option('display.max_rows', None)
# Print the dataframe
df

# %%
# drop all rows with any NaN and NaT values
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (50000, 14)

# %%
 data=df.sample(20000)

# %%
data
# Out:
#                                   Region      Country        Item Type  \
# 40392                 Sub-Saharan Africa     Tanzania        Beverages
# 14329  Central America and the Caribbean    Nicaragua       Vegetables
# 34388       Middle East and North Africa      Morocco        Cosmetics
# 26134                             Europe      Finland        Household
# 25769                             Europe      Belgium       Vegetables
# ...                                  ...          ...              ...
# 39976                 Sub-Saharan Africa       Uganda        Household
# 8524               Australia and Oceania        Palau        Beverages
# 35606       Middle East and North Africa      Somalia        Household
# 6758                                Asia  South Korea  Office Supplies
# 26994                             Europe       Poland             Meat
#
#       Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# ...

# %%
data.sort_values(sample_1.columns[13], 
                    axis=0,
                    inplace=True)

# %%
data
# Out:
#                                   Region                 Country  Item Type  \
# 16816                             Europe                Slovakia     Fruits
# 36884                 Sub-Saharan Africa              Cape Verde  Beverages
# 1                                   Asia              Bangladesh     Fruits
# 16818                             Europe                 Romania     Fruits
# 36885                 Sub-Saharan Africa                  Uganda  Beverages
# ...                                  ...                     ...        ...
# 16520  Central America and the Caribbean  Saint Kitts and Nevis   Cosmetics
# 28938                             Europe                  Serbia  Cosmetics
# 35436       Middle East and North Africa                   Egypt  Cosmetics
# 6938                                Asia             Philippines  Cosmetics
# 6943                                Asia                Maldives  Cosmetics
#
# ...

# %%
data.describe()
# Out:
#            Order ID    Units Sold    Unit Price     Unit Cost  Total Revenue  \
# count  2.000000e+04  20000.000000  20000.000000  20000.000000   2.000000e+04
# mean   5.482378e+08   5023.606250    266.525138    188.013872   1.335042e+06
# std    2.602185e+08   2886.838177    216.998790    175.690102   1.469592e+06
# min    1.000132e+08      1.000000      9.330000      6.920000   4.745000e+01
# 25%    3.230811e+08   2501.000000     81.730000     56.670000   2.831768e+05
# 50%    5.486275e+08   5044.000000    154.060000     97.440000   7.921339e+05
# 75%    7.742709e+08   7531.000000    437.200000    364.690000   1.827383e+06
# max    9.999995e+08  10000.000000    668.270000    524.960000   6.682032e+06
#
#          Total Cost  Total Profit
# count  2.000000e+04  2.000000e+04
# mean   9.415123e+05  3.935302e+05
# std    1.150954e+06  3.787315e+05
# min    3.179000e+01  1.446000e+01
# 25%    1.656117e+05  9.673410e+04
# 50%    4.767598e+05  2.834646e+05
# ...

# %%
#Group by region
data.groupby(["Region"]).mean()
# Out:
#                                        Order ID   Units Sold  Unit Price  \
# Region
# Asia                               5.526327e+08  5045.507776  268.716866
# Australia and Oceania              5.410201e+08  5130.328036  270.015232
# Central America and the Caribbean  5.481870e+08  4910.131148  267.720040
# Europe                             5.471232e+08  5020.303530  259.225749
# Middle East and North Africa       5.524295e+08  4959.250734  271.934516
# North America                      5.525821e+08  5190.701357  280.902805
# Sub-Saharan Africa                 5.467648e+08  5046.577357  267.234531
#
#                                     Unit Cost  Total Revenue    Total Cost  \
# Region
# Asia                               189.852610   1.351106e+06  9.572043e+05
# Australia and Oceania              190.735715   1.393013e+06  9.829735e+05
# Central America and the Caribbean  189.024767   1.293708e+06  9.109514e+05
# ...

# %%
#Group by region
data.groupby(["Country"]).mean()
# Out:
#                   Order ID   Units Sold  Unit Price   Unit Cost  \
# Country
# Afghanistan   5.483188e+08  4603.758242  275.115275  196.815934
# Albania       5.465776e+08  5304.504132  215.445455  143.991570
# Algeria       5.295976e+08  5021.862745  245.429608  170.952549
# Andorra       5.403748e+08  4422.412281  260.264649  184.813860
# Angola        5.245717e+08  4860.640625  243.656406  170.009141
# ...                    ...          ...         ...         ...
# Vatican City  5.313464e+08  4671.318966  264.855776  186.655172
# Vietnam       6.126985e+08  5771.272727  271.050909  195.296636
# Yemen         5.406026e+08  5191.697917  301.258021  219.039479
# Zambia        5.550698e+08  5035.740000  274.563800  191.981900
# Zimbabwe      5.752091e+08  5454.192661  285.721193  205.237615
#
#               Total Revenue    Total Cost   Total Profit
# Country
# Afghanistan    1.317795e+06  9.467780e+05  371016.958242
# Albania        1.180095e+06  7.836657e+05  396429.261818
# ...

# %%
#Group by iteam
data.groupby(["Item Type"]).mean()
# Out:
#                      Order ID   Units Sold  Unit Price  Unit Cost  \
# Item Type
# Baby Food        5.365451e+08  5007.230006      255.28     159.42
# Beverages        5.490382e+08  4991.079667       47.45      31.79
# Cereal           5.526766e+08  4990.656660      205.70     117.11
# Clothes          5.481978e+08  5020.552870      109.28      35.84
# Cosmetics        5.506128e+08  5007.723256      437.20     263.33
# Fruits           5.482438e+08  5036.918182        9.33       6.92
# Household        5.514300e+08  5010.036720      668.27     502.54
# Meat             5.420332e+08  4991.865645      421.89     364.69
# Office Supplies  5.483780e+08  4993.309792      651.21     524.96
# Personal Care    5.528795e+08  5156.020286       81.73      56.67
# Snacks           5.495283e+08  5019.424350      152.58      97.44
# Vegetables       5.491232e+08  5056.873306      154.06      90.93
#
#                  Total Revenue    Total Cost   Total Profit
# Item Type
# ...

# %%
#Group by sales chennel
data.groupby(["Sales Channel"]).mean()
# Out:
#                    Order ID   Units Sold  Unit Price   Unit Cost  \
# Sales Channel
# Offline        5.489351e+08  4993.265936  266.351992  187.926801
# Online         5.475480e+08  5053.620648  266.696424  188.100007
#
#                Total Revenue     Total Cost   Total Profit
# Sales Channel
# Offline         1.322940e+06  932944.158612  389995.748657
# Online          1.347015e+06  949988.316050  397026.673780

# %%
#Group by Order Priority
data.groupby(["Order Priority"]).mean()
# Out:
#                     Order ID   Units Sold  Unit Price   Unit Cost  \
# Order Priority
# C               5.519595e+08  5027.679648  267.409648  188.093605
# H               5.438220e+08  5006.911905  268.322052  189.176722
# L               5.465972e+08  5029.687192  264.416791  187.124097
# M               5.506804e+08  5030.346296  265.951623  187.655397
#
#                 Total Revenue     Total Cost   Total Profit
# Order Priority
# C                1.339898e+06  941979.463887  397918.106068
# H                1.347197e+06  950377.065252  396819.694185
# L                1.324471e+06  936857.241312  387613.966815
# M                1.328493e+06  936716.722235  391775.830679

# %%
#Group by Order Priority
data.groupby(["Region","Country"]).mean()
# Out:
#                                    Order ID   Units Sold  Unit Price  \
# Region             Country
# Asia               Bangladesh  5.508447e+08  5041.518182  249.849182
#                    Bhutan      5.241344e+08  5138.929204  259.581858
#                    Brunei      5.895938e+08  5193.084211  286.112526
#                    Cambodia    5.500092e+08  4752.768595  272.116198
#                    China       5.588185e+08  5335.974576  274.239068
# ...                                     ...          ...         ...
# Sub-Saharan Africa The Gambia  5.423792e+08  5069.915094  307.124906
#                    Togo        5.866488e+08  5465.720000  315.826400
#                    Uganda      4.980996e+08  4867.045455  257.580545
#                    Zambia      5.550698e+08  5035.740000  274.563800
#                    Zimbabwe    5.752091e+08  5454.192661  285.721193
#
#                                 Unit Cost  Total Revenue    Total Cost  \
# Region             Country
# ...

# %%
data.set_option('display.max_rows', None)
