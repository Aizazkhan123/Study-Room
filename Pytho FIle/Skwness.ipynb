# %% [markdown]
# # Name :Aizazkhan

# %%
import numpy as np
import os

print('getcwd:      ', os.getcwd())
# Out:
# getcwd:       C:\Users\khana\Downloads

# %%
# importing pandas as pd
import pandas as pd
# Creating the dataframe 
df = pd.read_csv("SalesRecords.csv")
#pd.set_option('display.max_rows', None)
# Print the dataframe
df
# Out:
#                    Region       Country  Item Type Sales Channel  \
# 0                    Asia  Turkmenistan     Fruits       Offline
# 1                    Asia    Bangladesh     Fruits        Online
# 2                    Asia     Indonesia     Fruits       Offline
# 3                    Asia      Mongolia     Fruits       Offline
# 4                    Asia     Singapore     Fruits       Offline
# ...                   ...           ...        ...           ...
# 49995  Sub-Saharan Africa       Namibia  Household       Offline
# 49996  Sub-Saharan Africa       Namibia  Household        Online
# 49997  Sub-Saharan Africa         Niger  Household       Offline
# 49998  Sub-Saharan Africa          Togo  Household        Online
# 49999  Sub-Saharan Africa  South Africa  Household       Offline
#
#       Order Priority  Order Date   Order ID   Ship Date  Units Sold  \
# 0                  M   2/26/2015  923827731    4/5/2015          10
# ...

# %%
# drop all rows with any NaN and NaT values
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (50000, 14)

# %%
df.describe()
# Out:
#            Order ID   Units Sold    Unit Price     Unit Cost  Total Revenue  \
# count  5.000000e+04  50000.00000  50000.000000  50000.000000   5.000000e+04
# mean   5.497330e+08   4999.61898    265.651350    187.322482   1.323716e+06
# std    2.609179e+08   2884.33508    216.916752    175.580570   1.463891e+06
# min    1.000132e+08      1.00000      9.330000      6.920000   2.799000e+01
# 25%    3.240070e+08   2498.00000     81.730000     35.840000   2.764871e+05
# 50%    5.504224e+08   5017.50000    154.060000     97.440000   7.813247e+05
# 75%    7.767824e+08   7493.25000    421.890000    263.330000   1.808642e+06
# max    9.999995e+08  10000.00000    668.270000    524.960000   6.682032e+06
#
#          Total Cost  Total Profit
# count  5.000000e+04  5.000000e+04
# mean   9.331574e+05  3.905587e+05
# std    1.145548e+06  3.777588e+05
# min    2.076000e+01  7.230000e+00
# 25%    1.606370e+05  9.415092e+04
# 50%    4.671040e+05  2.795364e+05
# 75%    1.190390e+06  5.642867e+05
# ...

# %%
np.median(df["Units Sold"])
# Out:
# 5017.5

# %% [markdown]
# # if we take as sample of data

# %%
 data=df.sample(30000)

# %%
data
# Out:
#                                   Region               Country  \
# 14475  Central America and the Caribbean              Honduras
# 4850                                Asia                 India
# 25608                             Europe        Czech Republic
# 14862  Central America and the Caribbean                 Haiti
# 5940                                Asia             Singapore
# ...                                  ...                   ...
# 41718                 Sub-Saharan Africa            Mauritius
# 49024                 Sub-Saharan Africa                Malawi
# 32347       Middle East and North Africa                  Iran
# 27040                             Europe               Georgia
# 15937  Central America and the Caribbean  Antigua and Barbuda
#
#              Item Type Sales Channel Order Priority  Order Date   Order ID  \
# 14475          Clothes       Offline              M   7/27/2017  363339173
# ...

# %%
data.shape
# Out:
# (30000, 14)

# %%
data.sort_values(data.columns[13], 
                    axis=0,
                    inplace=True)

# %%
data
# Out:
#                                   Region             Country  Item Type  \
# 11365  Central America and the Caribbean         Saint Lucia     Fruits
# 2                                   Asia           Indonesia     Fruits
# 16818                             Europe             Romania     Fruits
# 36885                 Sub-Saharan Africa              Uganda  Beverages
# 29657       Middle East and North Africa              Kuwait     Fruits
# ...                                  ...                 ...        ...
# 28946                             Europe           Macedonia  Cosmetics
# 16523  Central America and the Caribbean  Dominican Republic  Cosmetics
# 6943                                Asia            Maldives  Cosmetics
# 35440       Middle East and North Africa          Azerbaijan  Cosmetics
# 49273                 Sub-Saharan Africa               Ghana  Cosmetics
#
#       Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# ...

# %%
data.head(1000)
# Out:
#                                   Region      Country  Item Type  \
# 11365  Central America and the Caribbean  Saint Lucia     Fruits
# 2                                   Asia    Indonesia     Fruits
# 16818                             Europe      Romania     Fruits
# 36885                 Sub-Saharan Africa       Uganda  Beverages
# 29657       Middle East and North Africa       Kuwait     Fruits
# ...                                  ...          ...        ...
# 249                                 Asia  North Korea     Fruits
# 17269                             Europe      Croatia     Fruits
# 37302                 Sub-Saharan Africa     Tanzania     Fruits
# 11578  Central America and the Caribbean  El Salvador     Fruits
# 11579  Central America and the Caribbean     Honduras     Fruits
#
#       Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 11365       Offline              H   5/16/2016  817211854   6/11/2016
# ...

# %%
data.describe()
# Out:
#            Order ID    Units Sold    Unit Price     Unit Cost  Total Revenue  \
# count  3.000000e+04  30000.000000  30000.000000  30000.000000   3.000000e+04
# mean   5.501746e+08   4985.026433    264.692927    186.479384   1.319138e+06
# std    2.607019e+08   2890.365769    216.401085    174.986971   1.468261e+06
# min    1.000231e+08      1.000000      9.330000      6.920000   2.799000e+01
# 25%    3.260221e+08   2470.000000     81.730000     35.840000   2.748370e+05
# 50%    5.501870e+08   4992.500000    154.060000     97.440000   7.711356e+05
# 75%    7.776745e+08   7493.000000    421.890000    263.330000   1.793582e+06
# max    9.999514e+08  10000.000000    668.270000    524.960000   6.680027e+06
#
#          Total Cost  Total Profit
# count  3.000000e+04  3.000000e+04
# mean   9.296516e+05  3.894869e+05
# std    1.148008e+06  3.789106e+05
# min    2.076000e+01  7.230000e+00
# 25%    1.587155e+05  9.355918e+04
# 50%    4.608832e+05  2.761727e+05
# ...

# %%
data_2=data.drop(["Region","Country","Item Type","Sales Channel","Order Priority","Order Date","Ship Date"],axis=1)
data_2
# Out:
#         Order ID  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# 17251  112440192        2406        9.33       6.92       22447.98
# 40199  732682788        5974       47.45      31.79      283466.30
# 7885   945292270        1844       47.45      31.79       87497.80
# 46782  133408200        7306      255.28     159.42     1865075.68
# 28944  751371991        6524      668.27     502.54     4359793.48
# ...          ...         ...         ...        ...            ...
# 41679  638839805        5749       81.73      56.67      469865.77
# 18336  640211379        1629       47.45      31.79       77296.05
# 13834  114453351        8145       81.73      56.67      665690.85
# 7416   335024487          46      205.70     117.11        9462.20
# 10977  805741441        5653      651.21     524.96     3681290.13
#
#        Total Cost  Total Profit
# 17251    16649.52       5798.46
# 40199   189913.46      93552.84
# 7885     58620.76      28877.04
# ...

# %% [markdown]
# # finding skewness of sample data
# skewness = 0 : normally distributed.
#
# skewness > 0 : more weight in the left tail of the distribution.
#
# skewness < 0 : more weight in the right tail of the distribution.

# %%
# skewness along the index axis
skew=data_2.skew( )
skew

# kurtosis along the index axis
#kurt=data.kurt( )
#kurt
# Out:
# Order ID         0.005294
# Units Sold      -0.009539
# Unit Price       0.734732
# Unit Cost        0.895830
# Total Revenue    1.585617
# Total Cost       1.765106
# Total Profit     1.293886
# dtype: float64

# %% [markdown]
#   # Report
# # total revenue =  skewness > 0 : more weight in the left tail of the distribution.
#
# # total cost    =    skewness > 0 : more weight in the left tail of the distribution
#  # total profit  =    skewness > 0 : more weight in the left tail of the distribution.
#  # total solid  =    skewness  = 0 : normal  distribution
#
#  # unit price is closed to 1 so and grater then 0 more weight in the left tail of the distribution

# %% [markdown]
# # if we know that mean > median> mode> positve skewwness prove

# %%
mean=np.mean(data["Unit Price"])
median=np.median(data["Unit Price"])
print('mean of unit price =',mean)
print('median of unit price is =',median)
# Out:
# mean of unit price = 264.692927
# median of unit price is = 154.06

# %%
from scipy.stats import  skew
import seaborn as sns

# %%
import matplotlib.pyplot as plt
for col in data_2:
    print(col)
    print(skew(data_2[col]))
    
    
    plt.figure()
    sns.displot(data_2[col])
    plt.show()
# Out:
# Order ID
# 0.005293391078016626
# Units Sold
# -0.009538148490674251
# Unit Price
# 0.734695001779617
# Unit Cost
# 0.8957847462849747
# Total Revenue
# 1.5855379337405198
# Total Cost
# 1.7650178007733288
# Total Profit
# 1.2938214273129962

# %%
sns.pairplot(data_2)

# %%
df["Unit Cost"].skew()
# Out:
# 0.8934077531618682

# %%
df.corr()
# Out:
#                Order ID  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# Order ID       1.000000   -0.000234   -0.000397  -0.000663       0.001722
# Units Sold    -0.000234    1.000000   -0.007096  -0.006681       0.519834
# Unit Price    -0.000397   -0.007096    1.000000   0.985969       0.736209
# Unit Cost     -0.000663   -0.006681    0.985969   1.000000       0.725742
# Total Revenue  0.001722    0.519834    0.736209   0.725742       1.000000
# Total Cost     0.001665    0.468651    0.750962   0.761566       0.987668
# Total Profit   0.001623    0.593283    0.575675   0.502958       0.880111
#
#                Total Cost  Total Profit
# Order ID         0.001665      0.001623
# Units Sold       0.468651      0.593283
# Unit Price       0.750962      0.575675
# Unit Cost        0.761566      0.502958
# Total Revenue    0.987668      0.880111
# Total Cost       1.000000      0.794928
# Total Profit     0.794928      1.000000

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
x=df["Unit Cost"]
y=df["Unit Price"]
fig, ax = plt.subplots()
ax.plot(x, y, linewidth=0, marker='s', label='Data points')
ax.plot(x, intercept + slope * x, label=line)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.legend(facecolor='white')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# E:\Anocanda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# E:\Anocanda\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# E:\Anocanda\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'UnitPrice'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
