# %%
# importing pandas as pd
import pandas as pd
# Creating the dataframe 
df = pd.read_csv("nba.csv")
#pd.set_option('display.max_rows', None)
# Print the dataframe
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# drop all rows with any NaN and NaT values
df.dropna(inplace=True)

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary
# 0            Texas  7730337.0
# ...

# %%
df.shape
# Out:
# (364, 9)

# %%
df.describe()
# Out:
#            Number         Age      Weight        Salary
# count  364.000000  364.000000  364.000000  3.640000e+02
# mean    16.829670   26.615385  219.785714  4.620311e+06
# std     14.994162    4.233591   24.793099  5.119716e+06
# min      0.000000   19.000000  161.000000  5.572200e+04
# 25%      5.000000   24.000000  200.000000  1.000000e+06
# 50%     12.000000   26.000000  220.000000  2.515440e+06
# 75%     25.000000   29.000000  240.000000  6.149694e+06
# max     99.000000   40.000000  279.000000  2.287500e+07

# %% [markdown]
# # correlation in numpy ans seaborn

# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.stats import  skew
import seaborn as sns
np.corrcoef(df.Age,df.Salary)
# Out:
# array([[1.        , 0.15938493],
#        [0.15938493, 1.        ]])

# %%
from scipy import stats
stats.pearsonr(df.Age,df.Salary)
# Out:
# (0.1593849340088172, 0.0022889363036192375)

# %%
its mean age and Salarly  very lees positive and almost to close 0 so such as not correleation

# %%
df.corr()
# Out:
#           Number       Age    Weight    Salary
# Number  1.000000  0.025090  0.239768 -0.154655
# Age     0.025090  1.000000  0.058737  0.159385
# Weight  0.239768  0.058737  1.000000  0.144334
# Salary -0.154655  0.159385  0.144334  1.000000

# %%
sns.pairplot(df)

# %% [markdown]
# # in this data set  graph show there are no correlation with each other because every feature Number, Age , Weight , salarly  correlation  is close to 0

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# # in this heat map show that a value of correlation range as 0.2 to 0.0 to -0 its mean not correlation show in color

# %% [markdown]
# # Heat map _2

# %%
corrmat = df.corr()
  
f, ax = plt.subplots(figsize =(9, 8))
sns.heatmap(corrmat, ax = ax, cmap ="YlGnBu", linewidths = 0.1)
# Out:
# <AxesSubplot:>

# %%
corrmat = df.corr()

cg = sns.clustermap(corrmat, cmap ="YlGnBu", linewidths = 0.1);
plt.setp(cg.ax_heatmap.yaxis.get_majorticklabels(), rotation = 0)

cg

# %% [markdown]
# # Draw correlation grap of tow columns

# %%
x=df.Weight
y=df.Age
fig, ax = plt.subplots()
ax.plot(x, y, linewidth=0, marker='s', label='Data points')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.legend(facecolor='white')
plt.show()

# %% [markdown]
# # columns is not correlation b/w weight and Age
